# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"/content/Student_performance_data _.csv")
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
import matplotlib.pyplot as plt
name = [1001, 1002, 1003, 1004, 1005]
age = [17, 18, 15, 17, 17]
attendance_absence = [7, 0, 26, 14, 17]
study_hours = [19.833723, 15.408756, 4.210570, 10.028829, 4.672495]
# Adjusted marks to match the length of study_hours (5 elements)
marks = [65, 45, 80, 95, 65]

plt.scatter(study_hours, marks)
plt.title("Study Hours vs Marks")
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.show()

# %%
df-pd read_csvfile(."/content/Student_performance_data _.csv")
import= missing value

# %% [markdown]
# missing values chack
